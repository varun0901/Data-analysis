# %% [markdown]
# # Netflix Data Analysis

# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/asus/OneDrive/Desktop/data_analyst/netflix_data_analysis/netflix_titles.csv")
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# checking the null value
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
#removing the null values
data.dropna(inplace=True)

# %%
#checking if there is any duplicate values or not.

data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
# now we have data after removing the null values
data
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
# Checking the columns
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# using seaborn library 
import seaborn as sns

# %% [markdown]
# ## For series name "Zoom" show all the details of this series

# %%
data[data["title"].isin(["Zoom"])]
# Out:
#      show_id   type title      director  \
# 8805   s8806  Movie  Zoom  Peter Hewitt
#
#                                                    cast        country  \
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
#
#             date_added  release_year rating duration  \
# 8805  January 11, 2020          2006     PG   88 min
#
#                                listed_in  \
# 8805  Children & Family Movies, Comedies
#
#                                             description
# 8805  Dragged from civilian life, a former superhero...

# %%
data[data["title"].isin(["Zodiac"])]
# Out:
#      show_id   type   title       director  \
# 8802   s8803  Movie  Zodiac  David Fincher
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
#
#              date_added  release_year rating duration  \
# 8802  November 20, 2019          2007      R  158 min
#
#                            listed_in  \
# 8802  Cult Movies, Dramas, Thrillers
#
#                                             description
# 8802  A political cartoonist, a crime reporter and a...

# %% [markdown]
# ## In which year higest number of the TV series and movies were released, show with the bar graph

# %%
data_ = data.copy(deep=True)

# %%
g = data_.groupby(["release_year"]).count()

# %%
data_.groupby('release_year')['type'].value_counts()
# Out:
# release_year  type
# 1942          Movie        1
# 1944          Movie        1
# 1945          Movie        1
# 1946          Movie        1
# 1947          Movie        1
#                         ...
# 2019          TV Show     24
# 2020          Movie      409
#               TV Show     33
# 2021          Movie      146
#               TV Show     15
# Name: type, Length: 87, dtype: int64

# %% [markdown]
# ## Number of movies and TV shows we have in this data

# %%
data.groupby("type").type.count()
# Out:
# type
# Movie      5185
# TV Show     147
# Name: type, dtype: int64

# %% [markdown]
# ## Show the movies which release in year 2000

# %%
# we can do this using filtering option
data[(data["type"] == "Movie") & (data["release_year"]==2000)]
# Out:
#      show_id   type                                              title  \
# 350     s351  Movie                                      Space Cowboys
# 359     s360  Movie                       The Original Kings of Comedy
# 566     s567  Movie                                   Charlie's Angels
# 593     s594  Movie                                           Snow Day
# 779     s780  Movie                                  Battlefield Earth
# 952     s953  Movie                               The Whole Nine Yards
# 3472   s3473  Movie                        Rugrats in Paris: The Movie
# 4545   s4546  Movie             Monty Python: Before the Flying Circus
# 4723   s4724  Movie                                               Fiza
# 4956   s4957  Movie                        Phir Bhi Dil Hai Hindustani
# 5953   s5954  Movie                             Joseph: King of Dreams
# 6006   s6007  Movie                                            28 Days
# ...

# %% [markdown]
# ## Show the title of Movies which were released in India.

# %%
data[(data["type"] == "Movie") & (data["country"] == "India")]
# Out:
#      show_id   type                  title                 director  \
# 24       s25  Movie                  Jeans               S. Shankar
# 105     s106  Movie       Angamaly Diaries     Lijo Jose Pellissery
# 114     s115  Movie                 Anjaam             Rahul Rawail
# 116     s117  Movie                 Dhanak          Nagesh Kukunoor
# 118     s119  Movie                Gurgaon            Shanker Raman
# ...      ...    ...                    ...                      ...
# 8772   s8773  Movie  Yamla Pagla Deewana 2           Sangeeth Sivan
# 8773   s8774  Movie    Yanda Kartavya Aahe             Kedar Shinde
# 8798   s8799  Movie               Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800  Movie                  Zenda           Avadhoot Gupte
# 8806   s8807  Movie                 Zubaan              Mozez Singh
#
#                                                    cast country  \
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India
# ...

# %% [markdown]
# ## Show top 10 directors, who gave the higest number of TV shows & movies to netflix

# %%
data["director"].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              15
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Don Michael Paul          10
# David Dhawan               9
# Name: director, dtype: int64

# %% [markdown]
# ## show the top 10 movies where type is "category" is "Movie"

# %%
data[(data["type"] == "Movie") & (data["listed_in"] == "Comedies")].head(10)
# Out:
#      show_id   type                                        title  \
# 27       s28  Movie                                    Grown Ups
# 152     s153  Movie                Janoskians: Untold and Untrue
# 182     s183  Movie                  Welcome Home Roscoe Jenkins
# 342     s343  Movie                                  Major Payne
# 348     s349  Movie                                         Poms
# 562     s563  Movie  Austin Powers: International Man of Mystery
# 584     s585  Movie                       Not Another Teen Movie
# 931     s932  Movie                         Fun with Dick & Jane
# 948     s949  Movie                                       Swiped
# 1083   s1084  Movie                                 The Stand-In
#
#                  director                                               cast  \
# 27           Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# 152          Brett Weiner  Jai Brooks, Luke Brooks, James Yammouni, Danie...
# ...

# %% [markdown]
# ## Show data of comedy movies which were released in United States

# %%
data[(data["type"] == "Movie") & (data["listed_in"] == "Comedies") & (data["country"] == "United States")]
# Out:
#      show_id   type                                        title  \
# 27       s28  Movie                                    Grown Ups
# 152     s153  Movie                Janoskians: Untold and Untrue
# 182     s183  Movie                  Welcome Home Roscoe Jenkins
# 342     s343  Movie                                  Major Payne
# 562     s563  Movie  Austin Powers: International Man of Mystery
# ...      ...    ...                                          ...
# 8130   s8131  Movie                                    Superstar
# 8301   s8302  Movie                         The First Wives Club
# 8325   s8326  Movie              The Goods: Live Hard, Sell Hard
# 8608   s8609  Movie                             Total Frat Movie
# 8730   s8731  Movie                            Where's the Money
#
#               director                                               cast  \
# 27        Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# ...

# %% [markdown]
# # In how many movies or Tv shows, Tom cruise was cast?

# %%
data[data["cast"] == "Tom cruise"]  # not showing any because there is no movie released where only tom cruise has performed.
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
data[data["cast"].str.contains("Tom Cruise")]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#           date_added  release_year rating duration  \
# 341   August 1, 2021          1999      R  189 min
# 1254   March 1, 2021          1988      R  134 min
#
#                        listed_in  \
# 341   Dramas, Independent Movies
# 1254      Classic Movies, Dramas
#
#                                             description
# 341   Through chance, history and divine interventio...
# 1254  Motivated by money, a selfish workaholic seeki...

# %% [markdown]
# ## What are the different ratings explained by Netflix

# %%
(data["rating"].nunique())
# Out:
# 14

# %%
data["rating"].unique()
# Out:
# array(['TV-MA', 'TV-14', 'PG-13', 'PG', 'R', 'TV-PG', 'G', 'TV-Y7',
#        'TV-G', 'TV-Y', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ## how many movies got the TV-14 ratings in India

# %%
data[(data["type"] == "Movie") & (data["rating"]=='TV-14') & (data["country"] == "India")]
# Out:
#      show_id   type                  title              director  \
# 24       s25  Movie                  Jeans            S. Shankar
# 105     s106  Movie       Angamaly Diaries  Lijo Jose Pellissery
# 114     s115  Movie                 Anjaam          Rahul Rawail
# 118     s119  Movie                Gurgaon         Shanker Raman
# 126     s127  Movie                Shikara    Vidhu Vinod Chopra
# ...      ...    ...                    ...                   ...
# 8770   s8771  Movie                Yaadein          Subhash Ghai
# 8771   s8772  Movie       Yaara O Dildaara    Ksshitij Chaudhary
# 8772   s8773  Movie  Yamla Pagla Deewana 2        Sangeeth Sivan
# 8799   s8800  Movie                  Zenda        Avadhoot Gupte
# 8806   s8807  Movie                 Zubaan           Mozez Singh
#
#                                                    cast country  \
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India
# ...

# %% [markdown]
# ## How many movies got the R rating after 2018

# %%
data[(data["type"] == "Movie") & (data["rating"] == "R") & (data["release_year"] >= 2018)]
# Out:
#      show_id   type           title               director  \
# 81       s82  Movie            Kate  Cedric Nicolas-Troyan
# 247     s248  Movie      Sweet Girl   Brian Andrew Mendoza
# 437     s438  Movie      Cosmic Sin           Edward Drake
# 576     s577  Movie  Mary Magdalene            Garth Davis
# 589     s590  Movie        Red Joan            Trevor Nunn
# ...      ...    ...             ...                    ...
# 7042   s7043  Movie  I Am Vengeance            Ross Boyask
# 7636   s7637  Movie      Occupation            Luke Sparke
# 7950   s7951  Movie      Saving Zoë        Jeffrey G. Hunt
# 8676   s8677  Movie  Viking Destiny      David L.G. Hughes
# 8706   s8707  Movie  We the Animals         Jeremiah Zagar
#
#                                                    cast  \
# 81    Mary Elizabeth Winstead, Jun Kunimura, Woody H...
# 247   Jason Momoa, Isabela Merced, Manuel Garcia-Rul...
# 437   Frank Grillo, Bruce Willis, Brandon Thomas Lee...
# ...

# %% [markdown]
# ## What is the maximum duration of a show/ Movie on netflix

# %%
# firstly we have to seperate numbers and minutes
data[["minutes", "unit"]] = data["duration"].str.split(" ", expand=True)

# %%
data
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
data["minutes"].max()
# Out:
# '99'

# %%
tv_show_data = data[data["type"] == "TV Show"]
movies_data = data[data["type"] == "Movie"]

# %% [markdown]
# ## Country wise TV shows

# %%
tv_show_data.country.value_counts()
# Out:
# United States                                                    27
# United Kingdom                                                   19
# Japan                                                            10
# South Korea                                                      10
# Spain                                                             7
# India                                                             7
# Taiwan                                                            7
# France                                                            5
# Turkey                                                            5
# Thailand                                                          5
# Nigeria                                                           4
# Brazil                                                            4
# Canada                                                            3
# United States, Canada                                             2
# ...

# %% [markdown]
# ## Country wise Movies

# %%
movies_data.country.value_counts()
# Out:
# United States                   1819
# India                            868
# United Kingdom                   164
# Canada                           104
# Egypt                             90
#                                 ...
# Spain, United Kingdom              1
# Canada, Norway                     1
# France, Senegal, Belgium           1
# Uruguay, Guatemala                 1
# United Arab Emirates, Jordan       1
# Name: country, Length: 594, dtype: int64

# %% [markdown]
# ## Sort data by year (current to old)

# %%
data.sort_values(by=["release_year"], ascending=False)
# Out:
#      show_id     type                    title  \
# 1184   s1185    Movie      The Yin Yang Master
# 910     s911    Movie                  Monster
# 297     s298  TV Show                 Navarasa
# 299     s300    Movie                The Swarm
# 300     s301    Movie                     Vivo
# ...      ...      ...                      ...
# 8587   s8588    Movie              Thunderbolt
# 7294   s7295    Movie       Let There Be Light
# 7219   s7220    Movie  Know Your Enemy - Japan
# 8640   s8641    Movie         Tunisian Victory
# 8205   s8206    Movie     The Battle of Midway
#
#                                                director  \
# 1184                                          Li Weiran
# 910                                     Anthony Mandler
# 297   Bejoy Nambiar, Priyadarshan, Karthik Narain, V...
# 299                                      Just Philippot
# 300                      Kirk DeMicco, Brandon Jeffords
# ...
